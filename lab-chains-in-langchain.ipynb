# %% [markdown]
# # Lab | Chains in LangChain
#
# ## Outline
#
# * LLMChain
# * Sequential Chains
#   * SimpleSequentialChain
#   * SequentialChain
# * Router Chain

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')
HUGGINGFACEHUB_API_TOKEN = os.getenv('HUGGINGFACEHUB_API_TOKEN')

# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('/Users/basstianlopez/Desktop/it-studies/Curses/ironhack/week_16/day3/labs/lab-chains-in-langchain/data/Data.csv')

# %%
df.head()
#df.sample()
# Out:
#                    Product                                             Review
# 0     Queen Size Sheet Set  I ordered a king size set. My only criticism w...
# 1   Waterproof Phone Pouch  I loved the waterproof sac, although the openi...
# 2      Luxury Air Mattress  This mattress had a small hole in the top of i...
# 3           Pillows Insert  This is the best throw pillow fillers on Amazo...
# 4  Milk Frother Handheld\n   I loved this product. But they only seem to l...

# %% [markdown]
# ## LLMChain

# %%
# !pip install langchain_community

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
#from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
#from langchain_community.chains import LLMChain

# %%
#Replace None by your own value and justify
llm = ChatOpenAI(temperature=0)

#At a low temperature (0), the model almost always chooses the single most predictable next word, generating very consistent and factual results. 
#As you turn the dial up, the model is more likely to consider less obvious word choices, leading to more varied and creative, but less predictable, outputs

# %%
prompt = ChatPromptTemplate.from_template("Describe the product: {product}"
)
#Write a query that would take a variable to describe any product

# %%
chain = LLMChain(llm=llm, prompt=prompt)

# %%
product = "Queen Size Sheet Set" #Select a product type to be describe
chain.run(product)
# Out:
# 'The Queen Size Sheet Set is a bedding product that includes a fitted sheet, flat sheet, and two pillowcases designed to fit a queen size mattress. The sheets are typically made from soft and comfortable materials such as cotton, microfiber, or bamboo, and come in a variety of colors and patterns to suit different bedroom decor styles. The fitted sheet has elasticized edges to ensure a snug fit on the mattress, while the flat sheet provides a smooth and cozy layer to sleep on. The pillowcases are designed to fit standard queen size pillows. This sheet set is a convenient and stylish way to dress up your bed and create a comfortable sleeping environment.'

# %% [markdown]
# ## SimpleSequentialChain

# %%
from langchain.chains import SimpleSequentialChain

# %%
llm = ChatOpenAI(temperature=0.9)

# prompt template 1
first_prompt = ChatPromptTemplate.from_template("When you can use this the {product}"
    #Repeat the initial query or create a new query that would feed into the second prompt
)

# Chain 1
chain_one = LLMChain(llm=llm, prompt=first_prompt)

# %%
# prompt template 2
second_prompt = ChatPromptTemplate.from_template("What people say of give other uses different as {when}"
    #Write the second prompt query that takes an input variable whose input will come from the previous prompt"
)
# chain 2
chain_two = LLMChain(llm=llm, prompt=second_prompt)

# %%
overall_simple_chain = SimpleSequentialChain(chains=[chain_one, chain_two],verbose=True)

# %%
overall_simple_chain.run(product)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# You can use a Queen Size Sheet Set on a Queen size bed. It includes a fitted sheet, a flat sheet, and two pillowcases. It is typically used to cover and protect the mattress and pillows on a Queen size bed.
# However, some creative uses for a Queen Size Sheet Set include:
#
# 1. DIY curtains: Use the flat sheet to create curtains for your windows. Simply hem the edges and attach curtain rings or hooks for easy hanging.
#
# 2. Tablecloth: Use the flat sheet as a tablecloth for a large dining table or outdoor picnic. It can easily be washed and reused for future gatherings.
#
# 3. DIY bedding for pets: Cut up the fitted sheet and pillowcases to create cozy bedding for your pets. They will love snuggling up on the soft fabric.
#
# ...

# %% [markdown]
# **Repeat the above twice for different products**

# %%
product = "Luxury Air Mattress"
chain.run(product)

from langchain.chains import SimpleSequentialChain
llm = ChatOpenAI(temperature=0.9)
# prompt template 1
first_prompt = ChatPromptTemplate.from_template("How many years can i use {product}"
    #Repeat the initial query or create a new query that would feed into the second prompt
)
# Chain 1
chain_one = LLMChain(llm=llm, prompt=first_prompt) 
# prompt template 2
second_prompt = ChatPromptTemplate.from_template("After {years} when can i reciclying it"
    #Write the second prompt query that takes an input variable whose input will come from the previous prompt"
)
# chain 2
chain_two = LLMChain(llm=llm, prompt=second_prompt) 
overall_simple_chain = SimpleSequentialChain(chains=[chain_one, chain_two],verbose=True)
overall_simple_chain.run(product)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# The lifespan of a luxury air mattress can vary depending on the quality of the product and how well it is cared for. On average, a high-quality luxury air mattress can last anywhere from 5 to 10 years with proper maintenance and regular use. It is important to follow the manufacturer's guidelines for care and maintenance to ensure the longevity of your air mattress.
# When it comes time to recycle your luxury air mattress, you should first check with your local waste management facility to see if they accept air mattresses for recycling. Some facilities may have specific procedures for recycling mattresses, so it's important to follow their guidelines.
#
# ...

# %%
df.head()
# Out:
#                    Product                                             Review
# 0     Queen Size Sheet Set  I ordered a king size set. My only criticism w...
# 1   Waterproof Phone Pouch  I loved the waterproof sac, although the openi...
# 2      Luxury Air Mattress  This mattress had a small hole in the top of i...
# 3           Pillows Insert  This is the best throw pillow fillers on Amazo...
# 4  Milk Frother Handheld\n   I loved this product. But they only seem to l...

# %%
product = "Milk Frother Handheld\n"
chain.run(product)

from langchain.chains import SimpleSequentialChain
llm = ChatOpenAI(temperature=0.9)
# prompt template 1
first_prompt = ChatPromptTemplate.from_template("do the people love is this {product}?"
    #Repeat the initial query or create a new query that would feed into the second prompt
)
# Chain 1
chain_one = LLMChain(llm=llm, prompt=first_prompt) 
# prompt template 2
second_prompt = ChatPromptTemplate.from_template("What could be my status tu by that {prodcut}"
    #Write the second prompt query that takes an input variable whose input will come from the previous prompt"
)
# chain 2
chain_two = LLMChain(llm=llm, prompt=second_prompt) 
overall_simple_chain = SimpleSequentialChain(chains=[chain_one, chain_two],verbose=True)
overall_simple_chain.run(product)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# It ultimately depends on the individual's preferences and needs. Some people may love a handheld milk frother for its convenience and ease of use, while others may prefer a different method for frothing milk. It's best to read reviews and do research to see if a handheld milk frother is the right fit for you.
# Ultimately, you should consider your own needs and preferences when determining whether a handheld milk frother is the right choice for you. Some factors to consider include how often you will be using it, your budget, and your space limitations. Researching different options and reading reviews can help you make an informed decision.
#
# > Finished chain.
# ...

# %% [markdown]
# ## SequentialChain

# %%
from langchain.chains import SequentialChain

# %%
llm = ChatOpenAI(temperature=0.9)


first_prompt = ChatPromptTemplate.from_template("Translate the following product review to Spanish. Return ONLY the translation, no explanations:\n\n{Review}"
  #This prompt should translate a review
)

chain_one = LLMChain(llm=llm, prompt=first_prompt, 
                     output_key="espaReview" #Give a name to your output
                    )

# %%
second_prompt = ChatPromptTemplate.from_template("Summarize this Spanish review in one short sentence:\n{espaReview}"
    #Write a promplt to summarize a review
)

chain_two = LLMChain(llm=llm, prompt=second_prompt, 
                     output_key="sumR1" #give a name to this output
                    )

# %%
# prompt template 3: translate to english or other language
third_prompt = ChatPromptTemplate.from_template("Translate this Spanish review to German:\n{espaReview}"
)
# chain 3: input= Review and output= language
chain_three = LLMChain(llm=llm, prompt=third_prompt,
                       output_key="GermanReview"
                      )

# %%
# prompt template 4: follow up message that take as inputs the two previous prompts' variables
fourth_prompt = ChatPromptTemplate.from_template("Review in German: {GermanReview}\nSummary in Spanish: {sumR1}\n\nWrite a short analysis comparing these two versions."
)
chain_four = LLMChain(llm=llm, prompt=fourth_prompt,
                      output_key="stepback"
                     )

# %%
help(SequentialChain)
# Out:
# Help on class SequentialChain in module langchain.chains.sequential:
#
# class SequentialChain(langchain.chains.base.Chain)
#  |  SequentialChain(*args: Any, name: Optional[str] = None, memory: Optional[langchain_core.memory.BaseMemory] = None, callbacks: Union[List[langchain_core.callbacks.base.BaseCallbackHandler], langchain_core.callbacks.base.BaseCallbackManager, NoneType] = None, verbose: bool = None, tags: Optional[List[str]] = None, metadata: Optional[Dict[str, Any]] = None, callback_manager: Optional[langchain_core.callbacks.base.BaseCallbackManager] = None, chains: List[langchain.chains.base.Chain], input_variables: List[str], output_variables: List[str], return_all: bool = False) -> None
#  |
#  |  Chain where the outputs of one chain feed directly into next.
#  |
#  |  Method resolution order:
#  |      SequentialChain
#  |      langchain.chains.base.Chain
#  |      langchain_core.runnables.base.RunnableSerializable
#  |      langchain_core.load.serializable.Serializable
# ...

# %%
# overall_chain: input= Review 
# and output= English_Review,summary, followup_message
overall_chain = SequentialChain(
    chains=[chain_one, chain_two, chain_three, chain_four],
    input_variables= ["Review"],
    output_variables=["espaReview", "sumR1", "GermanReview","stepback"],
    verbose=True
)

# %%
review = df.Review[5]
overall_chain(review)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# > Finished chain.
# {'Review': "Je trouve le goût médiocre. La mousse ne tient pas, c'est bizarre. J'achète les mêmes dans le commerce et le goût est bien meilleur...\nVieux lot ou contrefaçon !?",
#  'espaReview': 'Encuentro el sabor mediocre. La espuma no se mantiene, es extraño. Compro los mismos en el comercio y el sabor es mucho mejor... ¿Lote viejo o falsificación!?',
#  'sumR1': 'El sabor es mediocre y la espuma no se mantiene, comparado con los mismos comprados en el comercio.',
#  'GermanReview': 'Ich finde den Geschmack mittelmäßig. Der Schaum hält nicht, das ist komisch. Ich kaufe die gleichen in Geschäften und der Geschmack ist viel besser... Alte Charge oder Fälschung!? \n\n(German)',
# ...

# %% [markdown]
# **Repeat the above twice for different products or reviews**

# %% [markdown]
# ## Router Chain

# %%
physics_template = """You are a very smart physics professor. \
You are great at answering questions about physics in a concise\
and easy to understand manner. \
When you don't know the answer to a question you admit\
that you don't know.

Here is a question:
{input}"""

math_template = """You are a very good mathematician. \
You are great at answering math questions. \
You are so good because you are able to break down \
hard problems into their component parts, 
answer the component parts, and then put them together\
to answer the broader question.

Here is a question:
{input}"""

history_template = """You are a very good historian. \
You have an excellent knowledge of and understanding of people,\
events and contexts from a range of historical periods. \
You have the ability to think, reflect, debate, discuss and \
evaluate the past. You have a respect for historical evidence\
and the ability to make use of it to support your explanations \
and judgements.

Here is a question:
{input}"""


computerscience_template = """ You are a successful computer scientist.\
You have a passion for creativity, collaboration,\
forward-thinking, confidence, strong problem-solving capabilities,\
understanding of theories and algorithms, and excellent communication \
skills. You are great at answering coding questions. \
You are so good because you know how to solve a problem by \
describing the solution in imperative steps \
that a machine can easily interpret and you know how to \
choose a solution that has a good balance between \
time complexity and space complexity. 

Here is a question:
{input}"""

biology_template = """You are an excellent biologist. \
You have a deep understanding of living organisms, \
from the molecular and cellular level to entire ecosystems. \
You are skilled at observing patterns in nature, analyzing biological data, \
and explaining complex processes like evolution, genetics, physiology, and ecology. \
You can clearly communicate how life functions and adapts, \
and you make connections between different biological concepts \
to answer challenging questions.

Here is a question:
{input}"""

# %%
prompt_infos = [
    {
        "name": "physics", 
        "description": "Good for answering questions about physics", 
        "prompt_template": physics_template
    },
    {
        "name": "math", 
        "description": "Good for answering math questions", 
        "prompt_template": math_template
    },
    {
        "name": "History", 
        "description": "Good for answering history questions", 
        "prompt_template": history_template
    },
    {
        "name": "computer science", 
        "description": "Good for answering computer science questions", 
        "prompt_template": computerscience_template
    },
    {
        "name": "biology",
        "description": "Good for answering biology questions",
        "prompt_template": biology_template
    }
]

# %%
from langchain.chains.router import MultiPromptChain
from langchain.chains.router.llm_router import LLMRouterChain,RouterOutputParser
from langchain.prompts import PromptTemplate

# %%
llm = ChatOpenAI(temperature=0)

# %%
destination_chains = {}
for p_info in prompt_infos:
    name = p_info["name"]
    prompt_template = p_info["prompt_template"]
    prompt = ChatPromptTemplate.from_template(template=prompt_template)
    chain = LLMChain(llm=llm, prompt=prompt)
    destination_chains[name] = chain  
    
destinations = [f"{p['name']}: {p['description']}" for p in prompt_infos]
destinations_str = "\n".join(destinations)

# %%
default_prompt = ChatPromptTemplate.from_template("{input}")
default_chain = LLMChain(llm=llm, prompt=default_prompt)

# %%
MULTI_PROMPT_ROUTER_TEMPLATE = """Given a raw text input to a \
language model select the model prompt best suited for the input. \
You will be given the names of the available prompts and a \
description of what the prompt is best suited for. \
You may also revise the original input if you think that revising\
it will ultimately lead to a better response from the language model.

<< FORMATTING >>
Return a markdown code snippet with a JSON object formatted to look like:
```json
{{{{
    "destination": string \ name of the prompt to use or "DEFAULT"
    "next_inputs": string \ a potentially modified version of the original input
}}}}
```

REMEMBER: "destination" MUST be one of the candidate prompt \
names specified below OR it can be "DEFAULT" if the input is not\
well suited for any of the candidate prompts.
REMEMBER: "next_inputs" can just be the original input \
if you don't think any modifications are needed.

<< CANDIDATE PROMPTS >>
{destinations}

<< INPUT >>
{{input}}

<< OUTPUT (remember to include the ```json)>>"""

# %%
router_template = MULTI_PROMPT_ROUTER_TEMPLATE.format(
    destinations=destinations_str
)
router_prompt = PromptTemplate(
    template=router_template,
    input_variables=["input"],
    output_parser=RouterOutputParser(),
)

router_chain = LLMRouterChain.from_llm(llm, router_prompt)

# %%
chain = MultiPromptChain(router_chain=router_chain, 
                         destination_chains=destination_chains, 
                         default_chain=default_chain, verbose=True
                        )
# Out:
# /var/folders/dk/w5mlpx9x4t9fj30jk64759lh0000gn/T/ipykernel_55678/3038952769.py:1: LangChainDeprecationWarning: Use RunnableLambda to select from multiple prompt templates. See example in API reference: https://api.python.langchain.com/en/latest/chains/langchain.chains.router.multi_prompt.MultiPromptChain.html
#   chain = MultiPromptChain(router_chain=router_chain,

# %%
chain.run("What is black body radiation?")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# physics: {'input': 'What is black body radiation?'}
# > Finished chain.
# "Black body radiation refers to the electromagnetic radiation emitted by a perfect black body, which is an idealized physical body that absorbs all incident electromagnetic radiation and emits radiation at all frequencies. The radiation emitted by a black body depends only on its temperature and follows a specific distribution known as Planck's law. This phenomenon is important in understanding the behavior of objects at high temperatures and is a key concept in the field of thermal physics."

# %%
chain.run("what is 2 + 2")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# math: {'input': 'what is 2 + 2'}
# > Finished chain.
# 'The answer to 2 + 2 is 4.'

# %%
chain.run("Why does every cell in our body contain DNA?")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# biology: {'input': 'Why does every cell in our body contain DNA?'}
# > Finished chain.
# ...

# %% [markdown]
# **Repeat the above at least once for different inputs and chains executions - Be creative!**

# %%
chain.run("Who was Atawalpa and wich country save his name as great lider?")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# History: {'input': 'Who was Atawalpa and which country saw him as a great leader?'}
# > Finished chain.
# "Atawalpa was the last ruling Inca emperor of the Inca Empire in South America. He was the son of Inca Emperor Huayna Capac and became emperor after his father's death in 1525. Atawalpa was seen as a great leader by the people of the Inca Empire, which encompassed present-day Peru, Ecuador, Bolivia, and parts of Chile and Argentina. However, his reign was cut short by the Spanish conquistadors led by Francisco Pizarro, who captured and eventually executed Atawalpa in 1533."

# %%
chain.run("what is a multicystic person and what happen in their bodies?")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# biology: {'input': 'what is a multicystic person and what happen in their bodies?'}
# > Finished chain.
# ...

# %%
chain.run("what speed need an airplane to achieve 50.000km of altitude succesfully?")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# physics: {'input': 'what speed does an airplane need to achieve 50,000 km of altitude successfully?'}
# > Finished chain.
# 'To achieve an altitude of 50,000 km, an airplane would need to reach escape velocity, which is approximately 11.2 km/s (kilometers per second). This speed is necessary to overcome the gravitational pull of the Earth and reach outer space.'

# %%
chain.run("how many planets arethe cientifics discover in milkyway galaxy?")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# None: {'input': 'how many planets arethe cientifics discover in milkyway galaxy?'}
# > Finished chain.
# 'As of now, scientists have discovered over 4,000 exoplanets in the Milky Way galaxy.'
